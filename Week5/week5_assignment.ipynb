# %%
import pandas as pd

# %%
df = pd.read_csv("./titanic.csv")

# %%
df
# Out:
#       Unnamed: 0  pclass                                             name  \
# 0              0       1                    Allen, Miss. Elisabeth Walton
# 1              1       1                   Allison, Master. Hudson Trevor
# 2              2       1                     Allison, Miss. Helen Loraine
# 3              3       1             Allison, Mr. Hudson Joshua Creighton
# 4              4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...          ...     ...                                              ...
# 1304        1304       3                             Zabour, Miss. Hileni
# 1305        1305       3                            Zabour, Miss. Thamine
# 1306        1306       3                        Zakarian, Mr. Mapriededer
# 1307        1307       3                              Zakarian, Mr. Ortin
# 1308        1308       3                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', as_frame=False)

# %%
X, y = mnist.data, mnist.target

# %%
df.describe()
# Out:
#         Unnamed: 0       pclass          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean    654.000000     2.294882    29.881135     0.498854     0.385027
# std     378.020061     0.837836    14.413500     1.041658     0.865560
# min       0.000000     1.000000     0.166700     0.000000     0.000000
# 25%     327.000000     2.000000    21.000000     0.000000     0.000000
# 50%     654.000000     3.000000    28.000000     0.000000     0.000000
# 75%     981.000000     3.000000    39.000000     1.000000     0.000000
# max    1308.000000     3.000000    80.000000     8.000000     9.000000
#
#               fare        body     survived
# count  1308.000000  121.000000  1309.000000
# mean     33.295479  160.809917     0.381971
# std      51.758668   97.696922     0.486055
# min       0.000000    1.000000     0.000000
# 25%       7.895800   72.000000     0.000000
# 50%      14.454200  155.000000     0.000000
# ...

# %% [markdown]
# ##### count가 데이터셋의 길이를 보여줌. 총 1309명의 데이터이기 때문에 이를 6:1 비율로 나누면 훈련 세트랑 테스트 세트는 각각 1122개랑 187개가 됨

# %%
X_train, X_test, y_train, y_test = X[:1122], X[1122:], y[:1122], y[1122:]

# %%
y_train_1 = (y_train == '1')
y_test_1 = (y_test == '1')

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_1)
# Out:
# SGDClassifier(random_state=42)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_train_pred = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3)
confusion_matrix(y_train_5, y_train_pred)
# Out:
# array([[976,  12],
#        [  9, 125]])

# %% [markdown]
# ### 정확도
# ##### 정확도: 전체 중 올바르게 맞춘 비율
# $976\over 976+12+9+125$=$1101\over 1122$=$0.98$ → 98% 정확도

# %% [markdown]
# ### 정밀도 vs 재현율
# ##### 정밀도:생존자라고 예측한 사람 중 실제로 생존한 사람의 비율
# $TP\over FP+TP$
# >$125\over 12+125 \\ =0.912$ → 91.2%
# <br>
#
# ##### 재현율:실제 생존자 중에서 생존자라고 올바르게 예측한 비율
# $TP\over FN+TP$
# > $125\over 9+125 \\ =0.925$ → 92.5%

# %% [markdown]
# ##### 재현율이 더 중요한 이유:
# ##### 생존자가 아닌 사람, 즉 사망자를 생존자라 판별하는 상황이 생기더라도 생존자를 놓치지 않는게 가장 결정적이기 때문!
